# %%
import os

print(os.getcwd())
# Out:
# c:\Users\rafii\Rafii\Coding\VScode\myResearch\ExperimentProject

# %%
import time

from core.experiment import Experiment

# %%
exp = Experiment(experiment_id="ipynb_test_instance")

# %%
start_time = time.time()

exp.train_model()
exp.save()

end_time = time.time()
print(f"{end_time - start_time} seconds")
# Out:
# Model training started!
# using device cuda:0
# progress:   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 start_time = time.time()
#       2
# ----> 3 exp.train_model()
#       4 exp.save()
#       5
#       6 end_time = time.time()
#
# File c:\Users\rafii\Rafii\Coding\VScode\myResearch\ExperimentProject\core\experiment.py:71, in Experiment.train_model(self, fold_index, n_fold)
#      69     self.experiment_state.datamodule = datamodule
#      70     trainer = Trainer(self.experiment_state)
# ---> 71     trainer.fit()
#      73     self.model_list.append(trainer.get_model())
#      75 return
#
# File c:\Users\rafii\Rafii\Coding\VScode\myResearch\ExperimentProject\core\trainer\trainer.py:75, in Trainer.fit(self)
#      69 self.trainer_state.current_epoch = epoch + 1
#      71 self.epoch_processor.process(
# ...
